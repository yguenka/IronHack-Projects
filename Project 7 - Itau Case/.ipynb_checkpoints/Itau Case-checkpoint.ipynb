# %% [markdown]
# # Importar bibliotecas

# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import plot_precision_recall_curve
import matplotlib.pyplot as plt
from sklearn.metrics import plot_roc_curve, roc_auc_score, roc_curve
from sklearn.linear_model import LogisticRegression
from yellowbrick.classifier import ROCAUC
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
# Out:
# C:\Users\yukar\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# C:\Users\yukar\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
rain = pd.read_csv('data/rain_data_aus.csv')

# %% [markdown]
# Dropando NaN

# %%
rain = rain.dropna()

# %% [markdown]
# Colocando em numéricas se choveu/choverá ou não.

# %%
rain['raintoday'] = rain['raintoday'].replace('No', 0).replace('Yes', 1)

# %%
rain['raintomorrow'] = rain['raintomorrow'].replace('No', 0).replace('Yes', 1)

# %% [markdown]
# Verificar correlação entre as variáveis.

# %%
rain.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col1 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col2 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col3 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col4 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col5 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col6 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col8 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col9 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col10 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col11 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col12 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col13 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col14 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col15 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col16 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col17 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col18 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col19 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow0_col20 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col0 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col2 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col3 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col4 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col5 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col6 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col7 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col8 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col9 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col10 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col11 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col12 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col13 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col14 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col15 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col16 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col17 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col18 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col19 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow1_col20 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col0 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col1 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col3 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col4 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col5 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col6 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col7 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col8 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col9 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col10 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col11 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col12 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col13 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col14 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col15 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col16 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_e5345e06_8a42_11ea_b15f_abd2d5119b6arow2_col17 {
#             background-color:  #e1dad6;

# %% [markdown]
# Dropando as colunas pois deu overfitting com elas.

# %%
wind_1 = pd.read_csv('data/wind_table_01.csv')
wind_2 = pd.read_csv('data/wind_table_02.csv')
wind_3 = pd.read_csv('data/wind_table_03.csv')
wind_4 = pd.read_csv('data/wind_table_04.csv')
wind_5 = pd.read_csv('data/wind_table_05.csv')
wind_6 = pd.read_csv('data/wind_table_06.csv')
wind_7 = pd.read_csv('data/wind_table_07.csv')
wind_8 = pd.read_csv('data/wind_table_08.csv')

# %%
wind_1.columns = wind_3.columns

# %%
wind_2.columns = wind_3.columns

# %%
wind = wind_1.append(wind_2, ignore_index=True).append(wind_3, ignore_index=True).append(wind_3, ignore_index=True).append(wind_4, ignore_index=True).append(wind_5, ignore_index=True).append(wind_6, ignore_index=True).append(wind_7, ignore_index=True).append(wind_8, ignore_index=True)

# %%
wind.head()
# Out:
#          date  location windgustdir  windgustspeed winddir9am winddir3pm  \
# 0  2007-11-01  Canberra          NW           30.0         SW         NW
# 1  2007-11-02  Canberra         ENE           39.0          E          W
# 2  2007-11-03  Canberra          NW           85.0          N        NNE
# 3  2007-11-04  Canberra          NW           54.0        WNW          W
# 4  2007-11-05  Canberra         SSE           50.0        SSE        ESE
#
#    windspeed9am  windspeed3pm
# 0           6.0          20.0
# 1           4.0          17.0
# 2           6.0           6.0
# 3          30.0          24.0
# 4          20.0          28.0

# %% [markdown]
# # Regressão Logistica - Baseline

# %%
X = rain[[ 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
       'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm',
       'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'raintoday',
       'temp', 'humidity', 'precipitation3pm','modelo_vigente', 'amountOfRain',
       'precipitation9am']]
y = rain['raintomorrow']
model = LogisticRegression(max_iter=10000)
model.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X, y)
# Out:
# 0.9997092929358183

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.75, random_state=7)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.9993539912573484

# %%
model.score(X_train, y_train)
# Out:
# 0.9992893597777635

# %% [markdown]
# ## Vamos melhorar !

# %% [markdown]
# Deu overfitting... Quais colunas tirar ?

# %%
rain.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col1 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col2 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col3 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col4 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col5 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col6 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col8 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col9 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col10 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col11 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col12 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col13 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col14 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col15 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col16 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col17 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col18 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col19 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow0_col20 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col0 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col2 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col3 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col4 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col5 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col6 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col7 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col8 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col9 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col10 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col11 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col12 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col13 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col14 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col15 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col16 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col17 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col18 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col19 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow1_col20 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col0 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col1 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col3 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col4 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col5 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col6 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col7 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col8 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col9 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col10 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col11 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col12 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col13 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col14 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col15 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col16 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_f2a2da9e_8a42_11ea_a39d_abd2d5119b6arow2_col17 {
#             background-color:  #e1dad6;

# %%
mask = rain['amountOfRain'] != 0
rain[mask]
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 5957    2009-01-19    Cobar     21.4     37.5       0.0         14.8
# 5960    2009-01-22    Cobar     21.8     30.7       0.0          8.0
# 5961    2009-01-23    Cobar     20.3     36.0      18.0          8.2
# 5971    2009-02-02    Cobar     27.6     40.3       0.0         14.4
# 5972    2009-02-03    Cobar     23.6     40.4       0.6         11.8
# ...            ...      ...      ...      ...       ...          ...
# 139046  2017-04-19   Darwin     25.2     33.5       0.0          4.8
# 139053  2017-04-26   Darwin     25.4     29.2       0.0          5.4
# 139054  2017-04-27   Darwin     24.4     27.4       0.2          2.2
# 139076  2017-05-19   Darwin     23.5     34.7       0.0          5.0
# 139087  2017-05-30   Darwin     22.5     32.3       0.0          6.6
#
#         sunshine  humidity9am  humidity3pm  pressure9am  ...  temp9am  \
# 5957         6.9         34.0         29.0       1013.1  ...     26.2
# 5960         5.9         71.0         63.0       1008.6  ...     24.4
# 5961        10.5         89.0         50.0       1008.6  ...     24.7
# 5971        10.9         32.0         20.0       1010.4  ...     32.0
# 5972        12.2         42.0         17.0       1008.4  ...     29.9
# ...          ...          ...          ...          ...  ...      ...
# 139046      11.2         70.0         46.0       1013.1  ...     28.9
# 139053       0.0         72.0         66.0       1011.0  ...     26.8
# 139054       0.0         73.0         86.0       1011.4  ...     25.5
# 139076      11.2         64.0         28.0       1011.9  ...     27.2
# 139087      10.6         52.0         25.0       1014.9  ...     25.3
#
#         temp3pm  raintoday  amountOfRain  raintomorrow       temp  humidity  \
# 5957       34.1          0           4.8             1  47.000000      36.8
# 5960       27.3          0          18.0             1  38.840000      77.6
# 5961       33.4          1           8.6             1   2.885476      62.0
# 5971       38.5          0           0.6             0  50.360000      26.0
# 5972       38.7          0           1.6             1  50.480000      22.4
# ...         ...        ...           ...           ...        ...       ...
# 139046     33.1          0           1.8             1  42.200000      57.2
# 139053     28.9          0           0.2             0  37.040000      81.2
# 139054     25.9          0           3.4             1  34.880000     105.2
# 139076     33.5          0           0.2             0   2.163095      35.6
# 139087     31.7          0           0.2             0  40.760000      32.0
#
#         precipitation3pm  precipitation9am  modelo_vigente
# 5957                  12          4.800715        0.508444
# 5960                  14         17.000266        0.668741
# 5961                  13         22.201948        0.565887
# 5971                  12          6.331012        0.077857
# 5972                  15         19.546120        0.444288
# ...                  ...               ...             ...
# 139046                11          8.607460        0.105326
# 139053                16         14.014132        0.525196
# 139054                13         11.585576        0.888070
# 139076                19         16.722569        0.017473
# 139087                16          8.975344        0.023908
#
# [21813 rows x 23 columns]

# %% [markdown]
# Vamos ter que tirar o Amount of Rain e o Modelo Vigente,pois está diretamente relacionado ao overfitting.

# %%
X = rain[[ 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
       'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm',
       'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'raintoday',
       'temp', 'humidity', 'precipitation3pm','precipitation9am']]
y = rain['raintomorrow']
model = LogisticRegression(max_iter=10000)
model.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X, y)
# Out:
# 0.8372847960205433

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.75, random_state=7)
model.score(X_test, y_test)
# Out:
# 0.8377010702211504

# %%
model.score(X_train, y_train)
# Out:
# 0.8360359196330512

# %%
confusion_matrix(y_test, model.predict(X_test))
# Out:
# array([[34050,  2074],
#        [ 5463,  4852]], dtype=int64)

# %%
plot_confusion_matrix(model, X_test, y_test, values_format='.0f')
plt.grid(False)

# %% [markdown]
# Taxa de acerto está quanto ?

# %%
precision_score(y, model.predict(X))
# Out:
# 0.7020218401989404

# %% [markdown]
# E a taxa de captura ?

# %%
recall_score(y, model.predict(X))
# Out:
# 0.47009846510280917

# %% [markdown]
# ### Que tal aumentar a taxa de acertos ?

# %%
y_pred = model.predict_proba(X)[:, 1] > 0.8

# %%
sns.heatmap(confusion_matrix(y, y_pred), annot=True, cmap='viridis', fmt="d", annot_kws={'verticalalignment':'top'})
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# %% [markdown]
# Taxa de acerto está em quanto ?

# %%
precision_score(y, y_pred)
# Out:
# 0.9100116867939229

# %% [markdown]
# E a taxa de captura ?

# %%
recall_score(y, y_pred)
# Out:
# 0.16912829423689546

# %% [markdown]
# ### E se diminuir a taxa de acertos ?

# %%
y_pred = model.predict_proba(X)[:, 1] > 0.2
sns.heatmap(confusion_matrix(y, y_pred), annot=True, cmap='viridis', fmt="d")

# %% [markdown]
# Taxa de acerto está em quanto ?

# %%
precision_score(y, y_pred)
# Out:
# 0.47346350412789934

# %% [markdown]
# E a taxa de captura ?

# %%
recall_score(y, y_pred)
# Out:
# 0.7847523892267594

# %% [markdown]
# Se quer aumentar a taxa de acerto, a taxa de captura diminui.
#
# Se quiser aumentar a taxa de captura, a taxa de acerto diminui.

# %% [markdown]
# ### Mesclar as duas planilhas pra ver no que pode dar ?

# %%
rain.head()
# Out:
#             date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 5939  2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 5940  2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 5942  2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 5943  2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# 5944  2009-01-06    Cobar     24.2     41.0       0.0         11.2       8.4
#
#       humidity9am  humidity3pm  pressure9am  ...  temp9am  temp3pm  raintoday  \
# 5939         20.0         13.0       1006.3  ...     26.6     33.4          0
# 5940         30.0          8.0       1012.9  ...     20.3     27.0          0
# 5942         42.0         22.0       1012.3  ...     28.7     34.9          0
# 5943         37.0         22.0       1012.7  ...     29.1     35.6          0
# 5944         19.0         15.0       1010.7  ...     33.6     37.6          0
#
#       amountOfRain  raintomorrow   temp  humidity  precipitation3pm  \
# 5939           0.0             0  44.24      17.6                 5
# 5940           0.0             0  36.68      11.6                 9
# 5942           0.0             0  47.12      28.4                11
# 5943           0.0             0  48.08      28.4                10
# 5944           0.0             0  51.20      20.0                 9
#
#       precipitation9am  modelo_vigente
# 5939         15.165784        0.011320
# 5940          9.750834        0.001683
# 5942          5.557986        0.061026
# 5943         17.820001        0.010724
# 5944         13.217116        0.103292
#
# [5 rows x 23 columns]

# %%
wind.head()
# Out:
#          date  location windgustdir  windgustspeed winddir9am winddir3pm  \
# 0  2007-11-01  Canberra          NW           30.0         SW         NW
# 1  2007-11-02  Canberra         ENE           39.0          E          W
# 2  2007-11-03  Canberra          NW           85.0          N        NNE
# 3  2007-11-04  Canberra          NW           54.0        WNW          W
# 4  2007-11-05  Canberra         SSE           50.0        SSE        ESE
#
#    windspeed9am  windspeed3pm
# 0           6.0          20.0
# 1           4.0          17.0
# 2           6.0           6.0
# 3          30.0          24.0
# 4          20.0          28.0

# %%
df = rain.merge(wind, on=['date','location'], how='left').drop_duplicates().drop(columns=['date', 'location']).fillna(0)

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col1 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col2 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col3 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col4 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col5 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col6 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col7 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col8 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col9 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col10 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col11 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col12 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col13 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col14 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col15 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col16 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col17 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col18 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col19 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col20 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col21 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col22 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow0_col23 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col0 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col2 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col3 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col4 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col7 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col8 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col9 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col11 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col12 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col14 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col15 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col16 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col18 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col19 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col20 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col21 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col22 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow1_col23 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col0 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col1 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col3 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col4 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col5 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col6 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col7 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col8 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col9 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col10 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_eb74ae46_8a5e_11ea_82a0_abd2d5119b6arow2_col11 {
#             background-color:  #96b7ff;

# %%
sns.heatmap(df.corr())

# %% [markdown]
# ### Usando apenas a velocidade do vento, como fica ?

# %%
df['raintomorrow'].value_counts()
# Out:
# 0    110316
# 1     31877
# Name: raintomorrow, dtype: int64

# %%
X = df[['windgustspeed', 'windspeed9am','windspeed3pm']]
y = df['raintomorrow']
model = LogisticRegression()
model.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X, y)
# Out:
# 0.7767541299501382

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.75, random_state=7)
model.score(X_test, y_test)
# Out:
# 0.7772516292371888

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus = RandomUnderSampler(random_state=7)
X_resampled, y_resampled = rus.fit_resample(X, y)

# %%
y_resampled.value_counts()
# Out:
# 1    31877
# 0    31877
# Name: raintomorrow, dtype: int64

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_resampled, y_resampled)
# Out:
# C:\Users\yukar\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X_resampled, y_resampled)
# Out:
# 0.764752015559808

# %%
precision_score(y_resampled, model.predict(X_resampled))
# Out:
# 0.7658528902189321

# %%
recall_score(y_resampled, model.predict(X_resampled))
# Out:
# 0.7626815572356245

# %%
model.score(X_train, y_train)
# Out:
# 0.775261618093845

# %%
plot_confusion_matrix(model, X_test, y_test, values_format='.0f')
plt.grid(False)

# %% [markdown]
# A taxa de acerto, está quanto ?

# %%
precision_score(y, model.predict(X))
# Out:
# 0.6034214618973561

# %% [markdown]
# E a taxa de captura ?

# %%
recall_score(y, model.predict(X))
# Out:
# 0.012171785299745897

# %% [markdown]
# ### E se colocar dummies ?

# %%
dfd = pd.get_dummies(df)

# %%
X = dfd[['mintemp', 'maxtemp', 'rainfall', 'evaporation', 'sunshine',
       'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm', 'cloud9am',
       'cloud3pm', 'temp9am', 'temp3pm', 'raintoday',
       'temp', 'humidity', 'precipitation3pm',
       'precipitation9am', 'windgustspeed', 'windspeed9am',
       'windspeed3pm', 'windgustdir_0', 'windgustdir_E', 'windgustdir_ENE',
       'windgustdir_ESE', 'windgustdir_N', 'windgustdir_NE', 'windgustdir_NNE',
       'windgustdir_NNW', 'windgustdir_NW', 'windgustdir_S', 'windgustdir_SE',
       'windgustdir_SSE', 'windgustdir_SSW', 'windgustdir_SW', 'windgustdir_W',
       'windgustdir_WNW', 'windgustdir_WSW', 'winddir9am_0', 'winddir9am_E',
       'winddir9am_ENE', 'winddir9am_ESE', 'winddir9am_N', 'winddir9am_NE',
       'winddir9am_NNE', 'winddir9am_NNW', 'winddir9am_NW', 'winddir9am_S',
       'winddir9am_SE', 'winddir9am_SSE', 'winddir9am_SSW', 'winddir9am_SW',
       'winddir9am_W', 'winddir9am_WNW', 'winddir9am_WSW', 'winddir3pm_0',
       'winddir3pm_E', 'winddir3pm_ENE', 'winddir3pm_ESE', 'winddir3pm_N',
       'winddir3pm_NE', 'winddir3pm_NNE', 'winddir3pm_NNW', 'winddir3pm_NW',
       'winddir3pm_S', 'winddir3pm_SE', 'winddir3pm_SSE', 'winddir3pm_SSW',
       'winddir3pm_SW', 'winddir3pm_W', 'winddir3pm_WNW', 'winddir3pm_WSW']]
y = dfd['raintomorrow']
model = LogisticRegression(max_iter=10000)
model.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X, y)
# Out:
# 0.8389794153017378

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.75, random_state=7)
model.score(X_test, y_test)
# Out:
# 0.8392517230062356

# %%
model.score(X_train, y_train)
# Out:
# 0.8381624845279622

# %%
plot_confusion_matrix(model, X_test, y_test, values_format='.0f')
plt.grid(False)

# %% [markdown]
# ### Visualizando os cotovelos...

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,20))
visualizer.fit(dfd)
visualizer.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-195-efd7a37871ca> in <module>
#       1 model = KMeans()
#       2 visualizer = KElbowVisualizer(model, k=(1,20))
# ----> 3 visualizer.fit(dfd)
#       4 visualizer.show()
#
# ~\AppData\Roaming\Python\Python37\site-packages\yellowbrick\cluster\elbow.py in fit(self, X, y, **kwargs)
#     310             # Set the k value and fit the model
#     311             self.estimator.set_params(n_clusters=k)
# --> 312             self.estimator.fit(X)
#     313
#     314             # Append the time and score to our plottable metrics
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     935                     max_iter=self.max_iter, init=init, verbose=self.verbose,
#     936                     precompute_distances=precompute_distances, tol=tol,
# --> 937                     x_squared_norms=x_squared_norms, random_state=seed)
#     938                 # determine if these results are the best so far
#     939                 if best_inertia is None or inertia < best_inertia:
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _kmeans_single_elkan(X, sample_weight, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     312     # init
#     313     centers = _init_centroids(X, n_clusters, init, random_state=random_state,
# --> 314                               x_squared_norms=x_squared_norms)
#     315     centers = np.ascontiguousarray(centers)
#     316     if verbose:
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _init_centroids(X, k, init, random_state, x_squared_norms, init_size)
#     624     if isinstance(init, str) and init == 'k-means++':
#     625         centers = _k_init(X, k, random_state=random_state,
# --> 626                           x_squared_norms=x_squared_norms)
#     627     elif isinstance(init, str) and init == 'random':
#     628         seeds = random_state.permutation(n_samples)[:k]
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _k_init(X, n_clusters, x_squared_norms, random_state, n_local_trials)
#     114         # Compute distances to center candidates
#     115         distance_to_candidates = euclidean_distances(
# --> 116             X[candidate_ids], X, Y_norm_squared=x_squared_norms, squared=True)
#     117
#     118         # update closest distances squared and potential for each candidate
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     303         distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     304         distances += XX
# --> 305         distances += YY
#     306     np.maximum(distances, 0, out=distances)
#     307
#
# KeyboardInterrupt:

# %%
model = KMeans(n_clusters=5)

# %%
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
dfd['labels'] = model.labels_

# %%
modelo = LogisticRegression(max_iter=10000)

# %%
mask = dfd['labels'] == 0
X = dfd[mask].drop(columns=['raintomorrow', 'amountOfRain', 'modelo_vigente', 'labels']) 
y = dfd[mask]['raintomorrow']
modelo.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
modelo.score(X,y)
# Out:
# 0.9399775617053104

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.75, random_state=7)
modelo.score(X_test, y_test)
# Out:
# 0.9391672899526302

# %%
# Out:
# 0.9424083769633508

# %% [markdown]
# Fazer função

# %%
# for item in range(0,4):
#     mask[item] = dfd['labels'] == item
#     X = dfd[mask].drop(columns=['raintomorrow', 'amountOfRain', 'modelo_vigente', 'labels']) 
#     y = dfd[mask]['raintomorrow']
#     modelo.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1013         try:
# -> 1014             self._set_with_engine(key, value)
#    1015         except com.SettingWithCopyError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _set_with_engine(self, key, value)
#    1053         try:
# -> 1054             self.index._engine.set_value(values, key, value)
#    1055             return
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# ValueError: setting an array element with a sequence.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-6ca82a30d631> in <module>
#       1 for item in range(0,4):
# ----> 2     mask[item] = dfd['labels'] == item
#       3     X = dfd[mask].drop(columns=['raintomorrow', 'amountOfRain', 'modelo_vigente', 'labels'])
#       4     y = dfd[mask]['raintomorrow']
#       5     modelo.fit(X,y)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1022                 self[:] = value
#    1023             else:
# -> 1024                 self.loc[key] = value
#    1025
#    1026         except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668             key = com.apply_if_callable(key, self.obj)
#     669         indexer = self._get_setitem_indexer(key)
# --> 670         self._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1052                 # setting for extensionarrays that store dicts. Need to decide
#    1053                 # if it's worth supporting that.
# -> 1054                 value = self._align_series(indexer, Series(value))
#    1055
#    1056             elif isinstance(value, ABCDataFrame):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    1206
#    1207         elif is_scalar(indexer):
# -> 1208             ax = self.obj._get_axis(1)
#    1209
#    1210             if ser.index.equals(ax):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis(self, axis)
#     421
#     422     def _get_axis(self, axis):
# --> 423         name = self._get_axis_name(axis)
#     424         return getattr(self, name)
#     425
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_name(cls, axis)
#     418             except KeyError:
#     419                 pass
# --> 420         raise ValueError(f"No axis named {axis} for object type {cls}")
#     421
#     422     def _get_axis(self, axis):
#
# ValueError: No axis named 1 for object type <class 'pandas.core.series.Series'>

# %% [markdown]
# ### E se não tivesse dropado os NaNs no começo ?

# %%
rain = pd.read_csv('data/rain_data_aus.csv')

# %%
rain.fillna(0)

# %%
rain['raintoday'] = rain['raintoday'].replace('No', 0).replace('Yes', 1)
rain['raintomorrow'] = rain['raintomorrow'].replace('No', 0).replace('Yes', 1)

# %%
df = rain.merge(wind, on=['date','location'], how='left').drop_duplicates().drop(columns=['date', 'location']).fillna(0)

# %%
df = pd.get_dummies(df)

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,20))
visualizer.fit(df.drop(columns=['raintomorrow']))
visualizer.show()

# %%
X = df[['mintemp', 'maxtemp', 'rainfall', 'evaporation', 'sunshine',
       'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm', 'cloud9am',
       'cloud3pm', 'temp9am', 'temp3pm', 'raintoday', 'temp', 'humidity',
       'precipitation3pm', 'precipitation9am',
       'windgustspeed', 'windspeed9am', 'windspeed3pm', 'windgustdir_0',
       'windgustdir_E', 'windgustdir_ENE', 'windgustdir_ESE', 'windgustdir_N',
       'windgustdir_NE', 'windgustdir_NNE', 'windgustdir_NNW',
       'windgustdir_NW', 'windgustdir_S', 'windgustdir_SE', 'windgustdir_SSE',
       'windgustdir_SSW', 'windgustdir_SW', 'windgustdir_W', 'windgustdir_WNW',
       'windgustdir_WSW', 'winddir9am_0', 'winddir9am_E', 'winddir9am_ENE',
       'winddir9am_ESE', 'winddir9am_N', 'winddir9am_NE', 'winddir9am_NNE',
       'winddir9am_NNW', 'winddir9am_NW', 'winddir9am_S', 'winddir9am_SE',
       'winddir9am_SSE', 'winddir9am_SSW', 'winddir9am_SW', 'winddir9am_W',
       'winddir9am_WNW', 'winddir9am_WSW', 'winddir3pm_0', 'winddir3pm_E',
       'winddir3pm_ENE', 'winddir3pm_ESE', 'winddir3pm_N', 'winddir3pm_NE',
       'winddir3pm_NNE', 'winddir3pm_NNW', 'winddir3pm_NW', 'winddir3pm_S',
       'winddir3pm_SE', 'winddir3pm_SSE', 'winddir3pm_SSW', 'winddir3pm_SW',
       'winddir3pm_W', 'winddir3pm_WNW', 'winddir3pm_WSW']]
model = KMeans(n_clusters=2)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
df['labels'] = model.labels_

# %%
mask = df['labels'] == 0
X = df[mask].drop(columns=['raintomorrow'])
y = df[mask]['raintomorrow']
modelo.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
modelo.score(X,y)
# Out:
# 0.8397125439737844

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.75, random_state=7)
modelo.score(X_test, y_test)
# Out:
# 0.83918044110324

# %%
modelo.score(X_train, y_train)
# Out:
# 0.8413088525854175

# %% [markdown]
# A taxa de acerto, está quanto ?

# %%
precision_score(y_test, modelo.predict(X_test))
# Out:
# 0.7222628882149953

# %% [markdown]
# E a taxa de captura ?

# %%
recall_score(y_test, modelo.predict(X_test))
# Out:
# 0.4842769500438212

# %%
plot_confusion_matrix(modelo, X_test, y_test, values_format='.0f')
plt.grid(False)

# %%
fig, ax =plt.subplots(1,2)
sns.countplot(y_test, ax=ax[0])
sns.countplot(y_train, ax=ax[1])
fig.show()
# Out:
# C:\Users\yukar\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %% [markdown]
# Com o Segundo label...

# %%
mask1 = df['labels'] == 1
X = df[mask1].drop(columns=['raintomorrow'])
y = df[mask1]['raintomorrow']
modelo.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
modelo.score(X,y)
# Out:
# 0.821416911524649

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.75, random_state=7)
modelo.score(X_test, y_test)
# Out:
# 0.822185142193848

# %%
modelo.score(X_train, y_train)
# Out:
# 0.8191118850674793

# %% [markdown]
# A taxa de acerto, está quanto ?

# %%
precision_score(y_test, modelo.predict(X_test))
# Out:
# 0.6861853325753269

# %% [markdown]
# E a taxa de captura ficou em...

# %%
recall_score(y_test, modelo.predict(X_test))
# Out:
# 1.0

# %%
plot_confusion_matrix(modelo, X_test, y_test, values_format='.0f')
plt.grid(False)

# %%
fig, ax =plt.subplots(1,2)
sns.countplot(y_test, ax=ax[0])
sns.countplot(y_train, ax=ax[1])
fig.show()
# Out:
# C:\Users\yukar\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %%
y.value_counts(normalize=True)
# Out:
# 0    0.77201
# 1    0.22799
# Name: raintomorrow, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.774666
# 1    0.225334
# Name: raintomorrow, dtype: float64

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.76404
# 1    0.23596
# Name: raintomorrow, dtype: float64

# %%
from sklearn.metrics import plot_precision_recall_curve

# %%
plot_precision_recall_curve(modelo, X, y)

# %%
from sklearn.metrics import plot_roc_curve, roc_auc_score, roc_curve

# %%
fig, ax = plt.subplots()

plot_roc_curve(modelo, X_test, y_test, color='red', ax= ax)
plot_roc_curve(modelo, X_train, y_train, color='blue', ax=ax)
